# %% [markdown]
# **This JupyterNotebook is for testing...**
# - the formulas defined in the "General link prediction," "PPI-specific link prediction," and "Preliminaries" sections of Yuen and Jansson's study
# - the score calculation functions written in score_formulas.py

# %%
# import libraries
import pandas as pd

# %%
# import my functions
from formulas import *
from myfunc import *
from scoring import *

# %% [markdown]
# ## 1st graph

# %%
e1 = {(1, 5), (3, 10), (5, 1), (5, 7), (5, 10), (6, 4), (6, 7), (6, 10), (10, 2)}
G1 = graph(e1)
visualizeGraph(G1)

# %% [markdown]
# ### Scores for `CN`, `RA`, `AA`, `p1`, and `pL3`

# %%
cn = convert_df(scores(G1,CN,None))
ra = convert_df(scores(G1,RA,None))
aa = convert_df(scores(G1,AA,None))
p = convert_df(scores(G1,p1,None))
p0 = convert_df(scores(G1,pL3,None))

print("CN")
display(cn)

print("\nRA")
display(ra)

print("\nAA")
display(aa)

print("\np1")
display(p)

print("\npL3")
display(p0)
# Out:
# CN
#       pairs  scores
# 0    (1, 2)       0
# 1    (1, 3)       0
# 2    (1, 4)       0
# 3    (1, 5)       0
# 4    (1, 6)       0
# 5    (1, 7)       1
# 6   (1, 10)       1
# 7    (2, 3)       1
# 8    (2, 4)       0
# 9    (2, 5)       1
# 10   (2, 6)       1
# 11   (2, 7)       0
# 12  (2, 10)       0
# 13   (3, 4)       0
# 14   (3, 5)       1
# 15   (3, 6)       1
# 16   (3, 7)       0
# 17  (3, 10)       0
# 18   (4, 5)       0
# 19   (4, 6)       0
# 20   (4, 7)       1
# 21  (4, 10)       1
# 22   (5, 6)       2
# 23   (5, 7)       0
# 24  (5, 10)       0
# 25   (6, 7)       0
# 26  (6, 10)       0
# 27  (7, 10)       2
# RA
#       pairs    scores
# 0    (1, 2)  0.000000
# 1    (1, 3)  0.000000
# 2    (1, 4)  0.000000
# 3    (1, 5)  0.000000
# 4    (1, 6)  0.000000
# 5    (1, 7)  0.333333
# 6   (1, 10)  0.333333
# 7    (2, 3)  0.250000
# 8    (2, 4)  0.000000
# 9    (2, 5)  0.250000
# 10   (2, 6)  0.250000
# 11   (2, 7)  0.000000
# 12  (2, 10)  0.000000
# ...

# %% [markdown]
# ### Scores for `p1`, `pL3`, `pL3N`, and `pL3Np`

# %%
# metric = SR
pN = convert_df(scores(G1,pL3N,SR))
pNp = convert_df(scores(G1,pL3Np,SR))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#       pairs    scores
# 0    (1, 2)  0.166667
# 1    (1, 3)  0.166667
# 2    (1, 4)  0.000000
# 3    (1, 5)  0.000000
# 4    (1, 6)  0.592593
# 5    (1, 7)  0.000000
# 6   (1, 10)  0.000000
# 7    (2, 3)  0.000000
# 8    (2, 4)  0.166667
# 9    (2, 5)  0.000000
# 10   (2, 6)  0.000000
# 11   (2, 7)  0.666667
# 12  (2, 10)  0.000000
# 13   (3, 4)  0.166667
# 14   (3, 5)  0.000000
# 15   (3, 6)  0.000000
# 16   (3, 7)  0.666667
# 17  (3, 10)  0.000000
# 18   (4, 5)  0.592593
# 19   (4, 6)  0.000000
# 20   (4, 7)  0.000000
# 21  (4, 10)  0.000000
# 22   (5, 6)  0.000000
# 23   (5, 7)  0.555556
# 24  (5, 10)  0.833333
# 25   (6, 7)  0.555556
# 26  (6, 10)  0.833333
# 27  (7, 10)  0.000000
# pL3Np
#       pairs    scores
# 0    (1, 2)  0.083333
# 1    (1, 3)  0.083333
# 2    (1, 4)  0.000000
# 3    (1, 5)  1.750000
# 4    (1, 6)  0.333333
# 5    (1, 7)  0.000000
# 6   (1, 10)  0.000000
# 7    (2, 3)  0.000000
# 8    (2, 4)  0.083333
# 9    (2, 5)  0.000000
# 10   (2, 6)  0.000000
# ...

# %%
# metric = JC
pN = convert_df(scores(G1,pL3N,JC))
pNp = convert_df(scores(G1,pL3Np,JC))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#       pairs    scores
# 0    (1, 2)  0.027778
# 1    (1, 3)  0.027778
# 2    (1, 4)  0.000000
# 3    (1, 5)  0.000000
# 4    (1, 6)  0.493827
# 5    (1, 7)  0.000000
# 6   (1, 10)  0.000000
# 7    (2, 3)  0.000000
# 8    (2, 4)  0.027778
# 9    (2, 5)  0.000000
# 10   (2, 6)  0.000000
# 11   (2, 7)  0.222222
# 12  (2, 10)  0.000000
# 13   (3, 4)  0.027778
# 14   (3, 5)  0.000000
# 15   (3, 6)  0.000000
# 16   (3, 7)  0.222222
# 17  (3, 10)  0.000000
# 18   (4, 5)  0.493827
# 19   (4, 6)  0.000000
# 20   (4, 7)  0.000000
# 21  (4, 10)  0.000000
# 22   (5, 6)  0.000000
# 23   (5, 7)  0.158420
# 24  (5, 10)  0.316840
# 25   (6, 7)  0.158420
# 26  (6, 10)  0.316840
# 27  (7, 10)  0.000000
# pL3Np
#       pairs    scores
# 0    (1, 2)  0.006944
# 1    (1, 3)  0.006944
# 2    (1, 4)  0.000000
# 3    (1, 5)  1.312500
# 4    (1, 6)  0.104167
# 5    (1, 7)  0.000000
# 6   (1, 10)  0.000000
# 7    (2, 3)  0.000000
# 8    (2, 4)  0.006944
# 9    (2, 5)  0.000000
# 10   (2, 6)  0.000000
# ...

# %% [markdown]
# ## 2nd graph

# %%
e2 = {(1, 5), (1, 7), (2, 4), (6, 2), (6, 3), (6, 5), (6, 7), (6, 10), (8, 3), (8, 6), (9, 1), (9, 3), (9, 7)}
G2 = graph(e2)
visualizeGraph(G2)

# %% [markdown]
# ### Scores for `CN`, `RA`, `AA`, `p1`, and `pL3`

# %%
cn = convert_df(scores(G2,CN,None))
ra = convert_df(scores(G2,RA,None))
aa = convert_df(scores(G2,AA,None))
p = convert_df(scores(G2,p1,None))
p0 = convert_df(scores(G2,pL3,None))

print("CN")
display(cn)

print("\nRA")
display(ra)

print("\nAA")
display(aa)

print("\np1")
display(p)

print("\npL3")
display(p0)
# Out:
# CN
#       pairs  scores
# 0    (1, 2)       0
# 1    (1, 3)       1
# 2    (1, 4)       0
# 3    (1, 5)       0
# 4    (1, 6)       2
# 5    (1, 7)       1
# 6    (1, 8)       0
# 7    (1, 9)       1
# 8   (1, 10)       0
# 9    (2, 3)       1
# 10   (2, 4)       0
# 11   (2, 5)       1
# 12   (2, 6)       0
# 13   (2, 7)       1
# 14   (2, 8)       1
# 15   (2, 9)       0
# 16  (2, 10)       1
# 17   (3, 4)       0
# 18   (3, 5)       1
# 19   (3, 6)       1
# 20   (3, 7)       2
# 21   (3, 8)       1
# 22   (3, 9)       0
# 23  (3, 10)       1
# 24   (4, 5)       0
# 25   (4, 6)       1
# 26   (4, 7)       0
# 27   (4, 8)       0
# 28   (4, 9)       0
# 29  (4, 10)       0
# 30   (5, 6)       0
# 31   (5, 7)       2
# 32   (5, 8)       1
# 33   (5, 9)       1
# 34  (5, 10)       1
# 35   (6, 7)       0
# 36   (6, 8)       1
# 37   (6, 9)       2
# 38  (6, 10)       0
# 39   (7, 8)       1
# 40   (7, 9)       1
# 41  (7, 10)       1
# 42   (8, 9)       1
# 43  (8, 10)       1
# ...

# %% [markdown]
# ### Scores for `p1`, `pL3`, `pL3N`, and `pL3Np`

# %%
# metric = SR
pN = convert_df(scores(G2,pL3N,SR))
pNp = convert_df(scores(G2,pL3Np,SR))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#       pairs    scores
# 0    (1, 2)  0.066667
# 1    (1, 3)  0.039506
# 2    (1, 4)  0.000000
# 3    (1, 5)  0.550000
# 4    (1, 6)  0.001543
# 5    (1, 7)  0.118519
# 6    (1, 8)  0.433333
# 7    (1, 9)  0.049383
# 8   (1, 10)  0.266667
# 9    (2, 3)  0.000000
# 10   (2, 4)  0.000000
# 11   (2, 5)  0.000000
# 12   (2, 6)  0.416667
# 13   (2, 7)  0.000000
# 14   (2, 8)  0.000000
# 15   (2, 9)  0.044444
# 16  (2, 10)  0.000000
# 17   (3, 4)  0.022222
# 18   (3, 5)  0.013889
# 19   (3, 6)  0.208333
# 20   (3, 7)  0.000000
# 21   (3, 8)  0.000000
# 22   (3, 9)  0.611111
# 23  (3, 10)  0.000000
# 24   (4, 5)  0.050000
# 25   (4, 6)  0.000000
# 26   (4, 7)  0.022222
# 27   (4, 8)  0.050000
# 28   (4, 9)  0.000000
# 29  (4, 10)  0.200000
# 30   (5, 6)  0.687500
# 31   (5, 7)  0.000000
# 32   (5, 8)  0.000000
# 33   (5, 9)  0.066667
# 34  (5, 10)  0.000000
# 35   (6, 7)  1.166667
# 36   (6, 8)  0.000000
# 37   (6, 9)  0.006173
# 38  (6, 10)  0.000000
# 39   (7, 8)  0.013889
# ...

# %%
# metric = JC
pN = convert_df(scores(G2,pL3N,JC))
pNp = convert_df(scores(G2,pL3Np,JC))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#       pairs    scores
# 0    (1, 2)  0.029630
# 1    (1, 3)  0.019753
# 2    (1, 4)  0.000000
# 3    (1, 5)  0.167863
# 4    (1, 6)  0.001157
# 5    (1, 7)  0.042524
# 6    (1, 8)  0.081983
# 7    (1, 9)  0.021948
# 8   (1, 10)  0.111111
# 9    (2, 3)  0.000000
# 10   (2, 4)  0.000000
# 11   (2, 5)  0.000000
# 12   (2, 6)  0.173611
# 13   (2, 7)  0.000000
# 14   (2, 8)  0.000000
# 15   (2, 9)  0.014815
# 16  (2, 10)  0.000000
# 17   (3, 4)  0.004444
# 18   (3, 5)  0.004630
# 19   (3, 6)  0.098349
# 20   (3, 7)  0.000000
# 21   (3, 8)  0.000000
# 22   (3, 9)  0.235654
# 23  (3, 10)  0.000000
# 24   (4, 5)  0.010000
# 25   (4, 6)  0.000000
# 26   (4, 7)  0.004444
# 27   (4, 8)  0.010000
# 28   (4, 9)  0.000000
# 29  (4, 10)  0.040000
# 30   (5, 6)  0.258141
# 31   (5, 7)  0.000000
# 32   (5, 8)  0.000000
# 33   (5, 9)  0.029630
# 34  (5, 10)  0.000000
# 35   (6, 7)  0.454432
# 36   (6, 8)  0.000000
# 37   (6, 9)  0.004115
# 38  (6, 10)  0.000000
# 39   (7, 8)  0.009259
# ...

# %% [markdown]
# ## 3rd graph

# %%
e3 = {(1, 10), (1, 13), (5, 1), (6, 1), (7, 5), (9, 3), (9, 7), (10, 1), (10, 4), (11, 7), (11, 8), (11, 12), (13, 1), (13, 12), (14, 5), (14, 7), (14, 9), (15, 2), (15, 11)}
G3 = graph(e3)
visualizeGraph(G3)

# %% [markdown]
# ### Scores for `CN`, `RA`, `AA`, `p1`, and `pL3`

# %%
cn = convert_df(scores(G3,CN,None))
ra = convert_df(scores(G3,RA,None))
aa = convert_df(scores(G3,AA,None))
p = convert_df(scores(G3,p1,None))
p0 = convert_df(scores(G3,pL3,None))

print("CN")
display(cn)

print("\nRA")
display(ra)

print("\nAA")
display(aa)

print("\np1")
display(p)

print("\npL3")
display(p0)
# Out:
# CN
#         pairs  scores
# 0      (1, 2)       0
# 1      (1, 3)       0
# 2      (1, 4)       1
# 3      (1, 5)       0
# 4      (1, 6)       0
# ..        ...     ...
# 100  (12, 14)       0
# 101  (12, 15)       1
# 102  (13, 14)       0
# 103  (13, 15)       0
# 104  (14, 15)       0
#
# [105 rows x 2 columns]
# RA
#         pairs  scores
# 0      (1, 2)    0.00
# 1      (1, 3)    0.00
# 2      (1, 4)    0.50
# 3      (1, 5)    0.00
# 4      (1, 6)    0.00
# ..        ...     ...
# 100  (12, 14)    0.00
# 101  (12, 15)    0.25
# 102  (13, 14)    0.00
# 103  (13, 15)    0.00
# 104  (14, 15)    0.00
#
# [105 rows x 2 columns]
# AA
#         pairs    scores
# 0      (1, 2)  0.000000
# 1      (1, 3)  0.000000
# 2      (1, 4)  1.442695
# 3      (1, 5)  0.000000
# 4      (1, 6)  0.000000
# ..        ...       ...
# 100  (12, 14)  0.000000
# 101  (12, 15)  0.721348
# 102  (13, 14)  0.000000
# 103  (13, 15)  0.000000
# 104  (14, 15)  0.000000
#
# [105 rows x 2 columns]
# p1
# ...

# %% [markdown]
# ### Scores for `p1`, `pL3`, `pL3N`, and `pL3Np`

# %%
# metric = SR
pN = convert_df(scores(G3,pL3N,SR))
pNp = convert_df(scores(G3,pL3Np,SR))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#         pairs    scores
# 0      (1, 2)  0.000000
# 1      (1, 3)  0.000000
# 2      (1, 4)  0.000000
# 3      (1, 5)  0.500000
# 4      (1, 6)  0.000000
# ..        ...       ...
# 100  (12, 14)  0.003086
# 101  (12, 15)  0.000000
# 102  (13, 14)  0.004630
# 103  (13, 15)  0.020833
# 104  (14, 15)  0.003086
#
# [105 rows x 2 columns]
# pL3Np
#         pairs    scores
# 0      (1, 2)  0.000000
# 1      (1, 3)  0.000000
# 2      (1, 4)  0.000000
# 3      (1, 5)  1.909722
# 4      (1, 6)  2.333333
# ..        ...       ...
# 100  (12, 14)  0.010417
# 101  (12, 15)  0.000000
# 102  (13, 14)  0.013889
# 103  (13, 15)  0.031250
# 104  (14, 15)  0.010417
#
# [105 rows x 2 columns]

# %%
# metric = JC
pN = convert_df(scores(G3,pL3N,JC))
pNp = convert_df(scores(G3,pL3Np,JC))

print("\npL3N")
display(pN)

print("\npL3Np")
display(pNp)
# Out:
# pL3N
#         pairs    scores
# 0      (1, 2)  0.000000
# 1      (1, 3)  0.000000
# 2      (1, 4)  0.000000
# 3      (1, 5)  0.250000
# 4      (1, 6)  0.000000
# ..        ...       ...
# 100  (12, 14)  0.000926
# 101  (12, 15)  0.000000
# 102  (13, 14)  0.001852
# 103  (13, 15)  0.010417
# 104  (14, 15)  0.000926
#
# [105 rows x 2 columns]
# pL3Np
#         pairs    scores
# 0      (1, 2)  0.000000
# 1      (1, 3)  0.000000
# 2      (1, 4)  0.000000
# 3      (1, 5)  1.295674
# 4      (1, 6)  1.611111
# ..        ...       ...
# 100  (12, 14)  0.002083
# 101  (12, 15)  0.000000
# 102  (13, 14)  0.003472
# 103  (13, 15)  0.008333
# 104  (14, 15)  0.002083
#
# [105 rows x 2 columns]
