# %%
import g_func
import cn_ra_aa

# %%
# test if simplified file works

# %%
# GRAPHS
n1_list = [0,1,2,3,4]
e1_list = [(0, 3), (1, 2), (2, 0), (3, 4), (4, 3), (1, 0), (2, 3)]
n2_list = [0,1,2,3,4,5,6,7]
e2_list = [(0, 6), (1, 7), (2, 0), (3, 2), (4, 3), (5, 6), (6, 1), (7, 2), (4, 6), (4, 5), (5, 0), (7, 3)]
n3_list = [0,1,2,3,4,5,6,7]
e3_list = [(0, 2), (1, 4), (2, 4), (3, 2), (4, 3), (5, 3), (6, 3), (7, 0), (7, 1), (5, 0), (5, 7), (1, 2), (1, 0), (0, 4)]

# %%
print("GRAPH 1")
print(" -- OG --")
g_func.graph(n1_list,e1_list)

print(" -- CN --")
g_func.graph(n1_list,cn_ra_aa.apply_method(n1_list,e1_list,cn_ra_aa.CN))

print(" -- RA --")
g_func.graph(n1_list,cn_ra_aa.apply_method(n1_list,e1_list,cn_ra_aa.RA))

print(" -- AA --")
g_func.graph(n1_list,cn_ra_aa.apply_method(n1_list,e1_list,cn_ra_aa.AA))
# Out:
# GRAPH 1
#  -- OG --
#  -- CN --
# 	 - proposed edges :  [(0, 2), (1, 3)]
# 	 - new edges :  [(1, 3)]
#  -- RA --
# 	 - proposed edges :  [(0, 2)]
# 	 - new edges :  []
#  -- AA --
# 	 - proposed edges :  [(0, 2)]
# 	 - new edges :  []

# %%
print("GRAPH 2")
print(" -- OG --")
g_func.graph(n2_list,e2_list)

print(" -- CN --")
g_func.graph(n2_list,cn_ra_aa.apply_method(n2_list,e2_list,cn_ra_aa.CN))

print(" -- RA --")
g_func.graph(n2_list,cn_ra_aa.apply_method(n2_list,e2_list,cn_ra_aa.RA))

print(" -- AA --")
g_func.graph(n3_list,cn_ra_aa.apply_method(n2_list,e2_list,cn_ra_aa.AA))
# Out:
# GRAPH 2
#  -- OG --
#  -- CN --
# 	 - proposed edges :  [(0, 4), (5, 6)]
# 	 - new edges :  [(0, 4)]
#  -- RA --
# 	 - proposed edges :  [(5, 6)]
# 	 - new edges :  []
#  -- AA --
# 	 - proposed edges :  [(5, 6)]
# 	 - new edges :  []

# %%
print("GRAPH 3")
print(" -- OG --")
g_func.graph(n3_list,e3_list)

print(" -- CN --")
g_func.graph(n3_list,cn_ra_aa.apply_method(n3_list,e3_list,cn_ra_aa.CN))

print(" -- RA --")
g_func.graph(n3_list,cn_ra_aa.apply_method(n3_list,e3_list,cn_ra_aa.RA))

print(" -- AA --")
g_func.graph(n3_list,cn_ra_aa.apply_method(n3_list,e3_list,cn_ra_aa.AA))
# Out:
# GRAPH 3
#  -- OG --
#  -- CN --
# 	 - proposed edges :  [(0, 1), (0, 3), (2, 4)]
# 	 - new edges :  [(0, 3)]
#  -- RA --
# 	 - proposed edges :  [(0, 1), (0, 3)]
# 	 - new edges :  [(0, 3)]
#  -- AA --
# 	 - proposed edges :  [(0, 1), (0, 3)]
# 	 - new edges :  [(0, 3)]

# %%
# testing score display (using graph 1)
print("-- CN --")
cn_ra_aa.print_scores(n1_list,e1_list,cn_ra_aa.scores_all(n1_list,e1_list,cn_ra_aa.CN))

print("-- RA --")
cn_ra_aa.print_scores(n1_list,e1_list,cn_ra_aa.scores_all(n1_list,e1_list,cn_ra_aa.RA))

print("-- AA --")
cn_ra_aa.print_scores(n1_list,e1_list,cn_ra_aa.scores_all(n1_list,e1_list,cn_ra_aa.AA))
# Out:
# -- CN --
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # testing score display (using graph 1)
#       2 print("-- CN --")
# ----> 3 cn_ra_aa.print_scores(n1_list,e1_list,cn_ra_aa.scores_all(n1_list,e1_list,cn_ra_aa.CN))
#       5 print("-- RA --")
#       6 cn_ra_aa.print_scores(n1_list,e1_list,cn_ra_aa.scores_all(n1_list,e1_list,cn_ra_aa.RA))
#
# File ~/Documents/PPI_L3/cn_ra_aa.py:38, in print_scores(n_list, e_list, method)
#      37 def print_scores(n_list:list[int],e_list:list[tuple],method) -> None :
# ---> 38     tab : list[list[float]] = scores_all(n_list,e_list,method)
#      40     print("     ",end="")
#      41     for i in range(len(n_list)) :
#
# File ~/Documents/PPI_L3/cn_ra_aa.py:35, in scores_all(n_list, e_list, method)
#      34 def scores_all(n_list:list[int],e_list:list[tuple],method) -> list[list[float]] :
# ---> 35     return [scores_indiv(n_list,e_list,n,method) for n in n_list]
#
# File ~/Documents/PPI_L3/cn_ra_aa.py:32, in scores_indiv(n_list, e_list, x, method)
#      31 def scores_indiv(n_list:list[int],e_list:list[tuple],x:int,method) -> list[float] :
# ---> 32     return [method(n_list,e_list,x,n) for n in n_list]
#
# TypeError: 'list' object is not callable
