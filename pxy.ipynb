# %%
import g_func
import cn_ra_aa
import pxy1

# %%
# GRAPHS
n1_list = [0,1,2,3,4]
e1_list = [(0, 3), (1, 2), (2, 0), (3, 4), (4, 3), (1, 0), (2, 3)]
n2_list = [0,1,2,3,4,5,6,7]
e2_list = [(0, 6), (1, 7), (2, 0), (3, 2), (4, 3), (5, 6), (6, 1), (7, 2), (4, 6), (4, 5), (5, 0), (7, 3)]
n3_list = [0,1,2,3,4,5,6,7]
e3_list = [(0, 2), (1, 4), (2, 4), (3, 2), (4, 3), (5, 3), (6, 3), (7, 0), (7, 1), (5, 0), (5, 7), (1, 2), (1, 0), (0, 4)]

# %%
# GRAPH 1
cn_ra_aa.print_scores(cn_ra_aa.scores_all(n1_list,e1_list,pxy1.p1))
print("-- OG --")
g_func.graph(n1_list,e1_list)
print("-- pxy1 --")
g_func.graph(n1_list,pxy1.apply_method(n1_list,e1_list,pxy1.p1))
# Out:
#      0    1    2    3    4
#
#     - - - - - - - - - - - - - -
#
# 0 | 4.00|5.00|5.00|6.00|1.00|
#
# 1 | 5.00|2.00|5.00|2.00|2.00|
#
# 2 | 5.00|5.00|4.00|6.00|1.00|
#
# 3 | 6.00|2.00|6.00|2.00|3.00|
#
# 4 | 1.00|2.00|1.00|3.00|    |
#
# -- OG --
# -- pxy1 --
# 	 - proposed edges :  [(1, 3), (1, 4)]
# 	 - new edges :  [(1, 3), (1, 4)]

# %%
# GRAPH 2
cn_ra_aa.print_scores(cn_ra_aa.scores_all(n2_list,e2_list,pxy1.p1))
print("-- OG --")
g_func.graph(n2_list,e2_list)
print("-- pxy1 --")
g_func.graph(n2_list,pxy1.apply_method(n2_list,e2_list,pxy1.p1))
# Out:
#      0    1    2    3    4    5    6    7
#
#     - - - - - - - - - - - - - - - - - - - -
#
# 0 | 2.00|2.00|5.00|3.00|3.00|6.00|7.00|2.00|
#
# 1 | 2.00|    |2.00|2.00|2.00|2.00|5.00|4.00|
#
# 2 | 5.00|2.00|2.00|5.00|3.00|2.00|3.00|5.00|
#
# 3 | 3.00|2.00|5.00|2.00|5.00|2.00|3.00|5.00|
#
# 4 | 3.00|2.00|3.00|5.00|2.00|6.00|7.00|2.00|
#
# 5 | 6.00|2.00|2.00|2.00|6.00|4.00|6.00|3.00|
#
# 6 | 7.00|5.00|3.00|3.00|7.00|6.00|4.00|2.00|
#
# 7 | 2.00|4.00|5.00|5.00|2.00|3.00|2.00|2.00|
#
# -- OG --
# -- pxy1 --
# 	 - proposed edges :  [(0, 3), (0, 4), (2, 4), (2, 6), (3, 6), (5, 7)]
# 	 - new edges :  [(0, 3), (0, 4), (2, 4), (2, 6), (3, 6), (5, 7)]

# %%
# GRAPH 3
cn_ra_aa.print_scores(cn_ra_aa.scores_all(n3_list,e3_list,pxy1.p1))
print("-- OG --")
g_func.graph(n3_list,e3_list)
print("-- pxy1 --")
g_func.graph(n3_list,pxy1.apply_method(n3_list,e3_list,pxy1.p1))
# Out:
#      0    1    2    3    4    5    6    7
#
#     - - - - - - - - - - - - - - - - - - - -
#
# 0 | 10.00|11.00|13.00|5.00|13.00|10.00|3.00|9.00|
#
# 1 | 11.00|8.00|11.00|6.00|11.00|6.00|2.00|9.00|
#
# 2 | 13.00|11.00|8.00|10.00|9.00|5.00|1.00|6.00|
#
# 3 | 5.00|6.00|10.00|2.00|10.00|8.00|4.00|5.00|
#
# 4 | 13.00|11.00|9.00|10.00|8.00|5.00|1.00|6.00|
#
# 5 | 10.00|6.00|5.00|8.00|5.00|2.00|    |6.00|
#
# 6 | 3.00|2.00|1.00|4.00|1.00|    |    |1.00|
#
# 7 | 9.00|9.00|6.00|5.00|6.00|6.00|1.00|4.00|
#
# -- OG --
# -- pxy1 --
# 	 - proposed edges :  [(1, 3), (1, 5), (2, 7), (4, 7), (5, 7)]
# 	 - new edges :  [(1, 3), (1, 5), (2, 7), (4, 7)]
